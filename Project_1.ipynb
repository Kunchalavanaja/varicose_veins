# %%
import pandas as pd
dataset=pd.read_csv('feeds.csv')

# %%
dataset
# Out:
#                    created_at  entry_id    temp     presure   ECG   Status
# 0   2024-12-27T18:28:44+00:00         1   32.02  1015.83435  1686   Normal
# 1   2024-12-27T18:29:06+00:00         2  178.89   -43.72762     0  Advance
# 2   2024-12-27T18:30:51+00:00         3   32.47  1015.76050     0   Normal
# 3   2024-12-27T18:31:13+00:00         4   32.04  1015.84406     0     Good
# 4   2024-12-27T18:31:34+00:00         5   31.75  1015.85913     0   Normal
# ..                        ...       ...     ...         ...   ...      ...
# 76  2024-12-27T18:58:10+00:00        77   29.82  1015.49969     0     Good
# 77  2024-12-27T18:58:32+00:00        78   29.83  1015.49408  4095   Normal
# 78  2024-12-27T18:58:54+00:00        79   29.83  1015.49829     0     Good
# 79  2024-12-27T18:59:16+00:00        80   29.82  1015.48315  4095   Normal
# 80  2024-12-27T18:59:38+00:00        81   29.81  1015.47205     0   Normal
#
# [81 rows x 6 columns]

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 81 entries, 0 to 80
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   created_at  81 non-null     object
#  1   entry_id    81 non-null     int64
#  2   temp        81 non-null     float64
#  3   presure     81 non-null     float64
#  4   ECG         81 non-null     int64
#  5   Status      81 non-null     object
# dtypes: float64(2), int64(2), object(2)
# memory usage: 3.9+ KB

# %%
X=dataset.iloc[:,[2,3,4]].values

# %%
X
# Out:
# array([[  32.02   , 1015.83435, 1686.     ],
#        [ 178.89   ,  -43.72762,    0.     ],
#        [  32.47   , 1015.7605 ,    0.     ],
#        [  32.04   , 1015.84406,    0.     ],
#        [  31.75   , 1015.85913,    0.     ],
#        [  31.56   , 1015.83423, 4095.     ],
#        [  31.37   , 1015.81909, 4095.     ],
#        [  31.12   , 1015.82312, 4095.     ],
#        [  30.82   , 1015.79907, 4061.     ],
#        [  30.9    , 1015.79047,  191.     ],
#        [  31.42   , 1015.79108, 4095.     ],
#        [  31.83   , 1015.78003, 4095.     ],
#        [  31.69   , 1015.80408,    0.     ],
#        [  31.16   , 1015.78607,    0.     ],
#        [  30.84   , 1015.78979,    0.     ],
#        [  30.63   , 1015.78369,    0.     ],
#        [  30.51   , 1015.77936, 4095.     ],
#        [  30.45   , 1015.77124, 4095.     ],
#        [  30.43   , 1015.76752, 4095.     ],
#        [  30.37   , 1015.76923,    0.     ],
#        [  30.33   , 1015.7774 ,    0.     ],
#        [  30.3    , 1015.77362,    0.     ],
#        [  30.28   , 1015.75409, 4095.     ],
#        [  30.19   , 1015.76953, 4095.     ],
#        [  30.12   , 1015.76483,    0.     ],
#        [  30.09   , 1015.76813, 4095.     ],
#        [  30.06   , 1015.74823,    0.     ],
#        [  30.05   , 1015.7475 ,    0.     ],
#        [  30.07   , 1015.75171,    0.     ],
#        [  30.06   , 1015.75372,    0.     ],
#        [  30.07   , 1015.73096,    0.     ],
#        [  30.05   , 1015.71875, 4095.     ],
#        [  30.05   , 1015.70642,    0.     ],
#        [  30.03   , 1015.69312, 3095.     ],
#        [  29.98   , 1015.66968,    0.     ],
#        [  29.94   , 1015.66565, 4095.     ],
#        [  29.93   , 1015.65198,    0.     ],
#        [  29.93   , 1015.64313,    0.     ],
#        [  29.93   , 1015.6344 ,    0.     ],
#        [  29.94   , 1015.63831, 4095.     ],
#        [  29.93   , 1015.62695, 4095.     ],
#        [  29.94   , 1015.61749, 4095.     ],
#        [  29.95   , 1015.61218, 2256.     ],
#        [  29.94   , 1015.61108,    0.     ],
#        [  29.94   , 1015.59253, 4095.     ],
#        [  29.93   , 1015.59003, 4095.     ],
#        [  29.92   , 1015.57812, 4095.     ],
#        [  29.93   , 1015.56366, 4095.     ],
#        [  29.94   , 1015.56091,    0.     ],
#        [  29.93   , 1015.54828,    0.     ],
#        [  29.92   , 1015.54858,    0.     ],
#        [  29.92   , 1015.54437, 1966.     ],
#        [  29.94   , 1015.53632,    0.     ],
#        [  29.99   , 1015.53821,    0.     ],
#        [  29.99   , 1015.53711, 4095.     ],
#        [  30.01   , 1015.54419, 4095.     ],
#        [  30.03   , 1015.52576, 4095.     ],
#        [  30.03   , 1015.51031, 2416.     ],
#        [  29.99   , 1015.5094 ,    0.     ],
#        [  29.96   , 1015.51331, 2121.     ],
#        [  29.94   , 1015.52045,    0.     ],
#        [  29.9    , 1015.51141, 4095.     ],
#        [  29.88   , 1015.51813, 2913.     ],
#        [  29.88   , 1015.51288,    0.     ],
#        [  29.89   , 1015.51221, 4095.     ],
#        [  29.9    , 1015.50269,    0.     ],
#        [  29.9    , 1015.51001,    0.     ],
#        [  29.88   , 1015.5094 , 4095.     ],
#        [  29.85   , 1015.5119 , 2670.     ],
#        [  29.85   , 1015.50812, 4095.     ],
#        [  29.84   , 1015.51294,    0.     ],
#        [  29.84   , 1015.51648, 4095.     ],
#        [  29.84   , 1015.50421,    0.     ],
#        [  29.83   , 1015.51093,    0.     ],
#        [  29.82   , 1015.49939, 4095.     ],
#        [  29.8    , 1015.49628, 2417.     ],
#        [  29.82   , 1015.49969,    0.     ],
#        [  29.83   , 1015.49408, 4095.     ],
#        [  29.83   , 1015.49829,    0.     ],
#        [  29.82   , 1015.48315, 4095.     ],
#        [  29.81   , 1015.47205,    0.     ]])

# %%
y=dataset.iloc[:,-1].values

# %%
y
# Out:
# array(['Normal', 'Advance', 'Normal', 'Good', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal', 'Good',
#        'Normal', 'Good', 'Normal', 'Normal', 'Normal', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Good', 'Normal', 'Good', 'Good', 'Good',
#        'Normal', 'Normal', 'Normal', 'Normal', 'Good', 'Normal', 'Normal',
#        'Normal', 'Normal', 'Good', 'Good', 'Good', 'Normal', 'Good',
#        'Good', 'Normal', 'Normal', 'Normal', 'Normal', 'Good', 'Normal',
#        'Good', 'Normal', 'Normal', 'Good', 'Normal', 'Good', 'Good',
#        'Normal', 'Normal', 'Normal', 'Good', 'Normal', 'Good', 'Good',
#        'Normal', 'Normal', 'Good', 'Normal', 'Good', 'Normal', 'Normal'],
#       dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print(X_train.shape,X_test.shape,y_train.shape,y_test.shape)
# Out:
# (64, 3) (17, 3) (64,) (17,)

# %%
from sklearn.linear_model import LogisticRegression
ai=LogisticRegression()
ai.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
ai.predict([[1,2,3]])
# Out:
# array(['Normal'], dtype=object)

# %%
y_ai=ai.predict(X_test)
